# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('stemmed_nouns.csv',index_col=None)

# %%
data
# Out:
#       Unnamed: 0                                        ingredients    cuisine
# 0              0  ['stew', 'meat', 'flour', 'cumin', 'oregano', ...      cuban
# 1              1  ['steak', 'broccoli', 'floret', 'wine', 'soy',...    chinese
# 2              2  ['chicken', 'breast', 'pineappl', 'slice', 'ma...   hawaiian
# 3              3  ['water', 'fish', 'sea', 'salt', 'ground', 'pe...   hawaiian
# 4              4  ['chicken', 'breast', 'shallot', 'pumpkin', 'k...     indian
# 5              5  ['leg', 'lamb', 'onion', 'garlic', 'caper', 't...     french
# 6              6  ['chicken', 'breast', 'cauliflow', 'oil', 'oni...      greek
# 7              7  ['potato', 'veget', 'oil', 'flour', 'beer', 'f...    english
# 8              8  ['lasagna', 'noodl', 'ricotta', 'spinach', 'mz...    italian
# 9              9  ['garlic', 'clove', 'shallot', 'chili', 'coria...   moroccan
# 10            10  ['ginger', 'garlic', 'bell', 'pepper', 'onion'...    chinese
# ...
